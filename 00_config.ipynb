# %%
dbutils.widgets.text("catalog", "nyc_taxi_project")
dbutils.widgets.text("env",     "prod")
dbutils.widgets.text("year",    "2025")
dbutils.widgets.text("month",   "01")

# %%
CATALOG = dbutils.widgets.get("catalog")
ENV     = dbutils.widgets.get("env")
YEAR    = dbutils.widgets.get("year")
MONTH   = dbutils.widgets.get("month")

# %%
LANDING_SCHEMA = f"{CATALOG}.landing"
BRONZE_SCHEMA  = f"{CATALOG}.bronze"
SILVER_SCHEMA  = f"{CATALOG}.silver"
GOLD_SCHEMA    = f"{CATALOG}.gold"

# %%
BRONZE_TABLE    = f"{CATALOG}.bronze.yellow_taxi"
SILVER1_TABLE   = f"{CATALOG}.silver.yellow_taxi_silver"
SILVER2_TABLE   = f"{CATALOG}.silver.yellow_taxi_silver_enriched"
GOLD_REVENUE    = f"{CATALOG}.gold.revenue_dashboard"
GOLD_TRIP       = f"{CATALOG}.gold.trip_analysis"
GOLD_VENDOR     = f"{CATALOG}.gold.vendor_performance"

# %%
LANDING_VOLUME  = f"/Volumes/{CATALOG}/landing/raw_files/"
LOOKUP_VOLUME   = f"/Volumes/{CATALOG}/landing/lookup_files/"
CHECKPOINT_BASE = f"/Volumes/{CATALOG}/landing/checkpoints"

# %%
BRONZE_CHECKPOINT   = f"{CHECKPOINT_BASE}/bronze/"
SILVER1_CHECKPOINT  = f"{CHECKPOINT_BASE}/silver/"
SILVER2_CHECKPOINT  = f"{CHECKPOINT_BASE}/silver2/"
GOLD_REV_CHECKPOINT = f"{CHECKPOINT_BASE}/gold_revenue/"
GOLD_TRIP_CHECKPOINT= f"{CHECKPOINT_BASE}/gold_trip/"
